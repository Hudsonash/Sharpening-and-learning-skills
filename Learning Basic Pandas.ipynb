# %% [markdown]
# # Pandas
# ---
# Pandas is a light-weight data frame for python.  Pandas is mainly used for data analysis, and is often partnered with both numpy and matplotlib's pyplot to further the strength of Pandas.  Pandas is typically imported as pd.

# %%
import pandas as pd

# %% [markdown]
# ### Elements of the DataFrame and Series
#
#
# **_Index_**: An index is similar to the rows in excel, or a primary key in a database.  It identifies the row and sorts the data according to the index.  A major difference in Pandas is an index value is not unique.  Index values can be repeated with no error (however, this may not be suitable for types of databases).  An index can be created by a list of values
#
# **_Series_**: A series is similar to a dictionary, containing a single column of data and a single index identifying the data.
# A series is created by calling the following function:
# ```
# pd.Series(data, index=index)
# ```
# Index defaults to the pattern of [0, 1, 2, ..., n] or index can be passed as a list of values.  Data can be a list of values, a dictionary (which creates both the index and the columns) or a scalar value.
#
# **_NaN_**: A standard missing number marker in Pandas

# %% [markdown]
# ### Series
# ##### Creation
# Creating Series are seen aboce in the definition of a series. Below are several examples of creating series:

# %%
## 3 ways to create Series
series_1 = pd.Series([2,4,6,8])
series_1
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %% [markdown]
# series_1 does not contain an index, and uses the default index of [0, 1, 2, ...].  dtype refers to the form of data, which when not entered in the function, becomes int64 if all integers

# %%
series_2 = pd.Series([2,4,6.5,8], index =['a','b', 'c', 'a'])
series_2
# Out:
# a    2.0
# b    4.0
# c    6.5
# a    8.0
# dtype: float64

# %% [markdown]
# Series_2 uses an index and displays that a Series' index does not have to be numerical nor unique.  Float64 is the data type due to the 6.5 being a float

# %%
series_3 = pd.Series({'i': 'do', 'not': 'like', 'green': 'eggs', 'and': 'ham', 'I': '2'})
series_3
# Out:
# I           2
# and       ham
# green    eggs
# i          do
# not      like
# dtype: object

# %% [markdown]
# Series_3 reads from a dictionary, using no numerical values. It's datatype (dtype) is object because several of the data types are strings, not numerical values

# %% [markdown]
# ### Slicing Series

# %%
## A series can be sliced like a dictionary
series_2['a']
# Out:
# a    2
# a    8
# dtype: float64

# %%
## A series can be sliced using integer values
series_3[2]
# Out:
# 'eggs'

# %%
## A series can be sliced in sets using regular slicing methods
series_1[:3]
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
## A series can be sliced using a list of integers
print(series_3[[3,1,4]])
## or a list of index values 
print('\n',series_3[['i','and','not']])
# Out:
# i        do
# and     ham
# not    like
# dtype: object
#
#  i        do
# and     ham
# not    like
# dtype: object

# %%
## A series can lastly be sliced using many different operations, such as median
series_2[series_2 > series_2.median()]
# Out:
# c    6.5
# a    8.0
# dtype: float64

# %% [markdown]
# ##### Operations and Series
# Series can be added, multiplied, divided, subtracted, and many more applications to a single series. For more information, see the [documentation of Series.](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html)  Several of the best operations and examples are seen below.

# %%
s_1_multiplied = series_1 * 4
s_1_multiplied
# Out:
# 0     8
# 1    16
# 2    24
# 3    32
# dtype: int64

# %%
s_1_special = series_1[0:2] + series_1[1:]
s_1_special
# Out:
# 0   NaN
# 1     8
# 2   NaN
# 3   NaN
# dtype: float64

# %% [markdown]
# ### Dataframe
# A dataframe is an extension of a series, with columns and indexes.  A dataframe may be created in the following ways:
# * **_Dictionary of Series_**: Key is the column name, value is the original series.  If a list of columns are passed within the function, it will overwrite the dictionary's column names
# * **_List of Lists_**: A dataframe can be created with a list of lists. Column names are also necessary to be passed for a list of lists in order to have a proper dataframe
# * **_List of Dicts_**: A list of dictionaries can create a dataframe.  Indexes are created by the keys and columns must be entered
#
# ##### Column Selection, Addition, Deletion
# * **_Addition_**: A column can be added in a similar way to a dictionary:
#
#         df['new_column_name] = data or combination of current columns
#
# * **_Deletion_**: A column can be deleted by calling:
#
#         del df['column_name']
# * **_Popped_**: A column can be removed from the current dataframe and stored in its own column by calling:
#
#         column = df.pop('column_name')
# * **_Assigning_** Assign creates a new column based on a current series, a lambda function, or an operation involving columns of the dataframe
#
#         updated_dataframe = df.assign(column_name = some function)
# * **_Slicing_**: A row can be selected as seen below and returns a series where the indexes are column names.  Several rows can be selected at a same time as seen below by calling integers to select certain entries
#
#         sliced_row = df.loc['row entry']
#         sliced_rows = df[3:5] (or other numbers)

# %%
## Creating a dataframe for testing and examples
df = pd.DataFrame([[4,5,3,1], [5,1,9,-2], [-6,2,1,0]], index = ['a','b','c'], columns = ['red', 'white', 'blue', 'green'])
df
# Out:
#    red  white  blue  green
# a    4      5     3      1
# b    5      1     9     -2
# c   -6      2     1      0

# %%
## Applying assign using a lambda function to create a new column
df_rw_ratios = df.assign(rw_ratio = lambda x: x['red'] / x['white'])
df_rw_ratios
# Out:
#    red  white  blue  green  rw_ratio
# a    4      5     3      1       0.8
# b    5      1     9     -2       5.0
# c   -6      2     1      0      -3.0

# %%
## Applying pop to a dataframe
green = df_rw_ratios.pop('green')
print(green)
print(df_rw_ratios)
# Out:
# a    1
# b   -2
# c    0
# Name: green, dtype: int64
#    red  white  blue  rw_ratio
# a    4      5     3       0.8
# b    5      1     9       5.0
# c   -6      2     1      -3.0

# %% [markdown]
# ##### Accessing Data in Pandas

# %% [markdown]
# ### Importing and Exporting Data
# The following data used is from the Canadian Government's Open Data portal. The data is

# %%
canadian_embassies_loc = '/Users/HudsonAccount/Desktop/embassies-consulates-list.json'
x = pd.read_json(canadian_embassies_loc)
y = x['data'].apply(pd.Series)
z = y['country'].apply(pd.Series)
a = y['offices'].apply(pd.Series)
z.set_index('eng')
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/core/index.py:6122: RuntimeWarning: unorderable types: int() > str(), sort order is undefined for incomparable objects
#   union = _union_indexes(indexes)
#                                                     country-id country-iso  \
# eng
# {'name': 'Afghanistan'}                                   1000          AF
# {'name': 'Antigua and Barbuda'}                          10000          AG
# {'name': 'Germany'}                                     100000          DE
# {'name': 'Ghana'}                                       101000          GH
# {'name': 'Greece'}                                      106000          GR
# {'name': 'Greenland'}                                   107000          GL
# {'name': 'Grenada'}                                     109000          GD
# {'name': 'Argentina'}                                    11000          AR
# {'name': 'Guadeloupe'}                                  110000          GP
# {'name': 'Guam'}                                        111000          GU
# {'name': 'Guatemala'}                                   112000          GT
# {'name': 'Guinea'}                                      114000          GN
# {'name': 'Guinea-Bissau'}                               115000          GW
# {'name': 'Guyana'}                                      116000          GY
# {'name': 'Haiti'}                                       117000          HT
# {'name': 'Hong Kong'}                                   120000          HK
# {'name': 'Honduras'}                                    121000          HN
# {'name': 'Hungary'}                                     124000          HU
# {'name': 'Iceland'}                                     125000          IS
# {'name': 'India'}                                       128000          IN
# {'name': 'Indonesia'}                                   130000          ID
# {'name': 'Iran'}                                        132000          IR
# {'name': 'Iraq'}                                        133000          IQ
# {'name': 'Ireland'}                                     134000          IE
# {'name': 'Israel, the West Bank and the Gaza St...      135000          IL
# {'name': 'Italy'}                                       136000          IT
# {'name': 'Côte d'Ivoire (Ivory Coast)'}                 137000          CI
# {'name': 'Jamaica'}                                     138000          JM
# {'name': 'Armenia'}                                      14000          AM
# {'name': 'Japan'}                                       140000          JP
# ...                                                        ...         ...
# {'name': 'Republic of Congo (Brazzaville)'}              63000          CG
# {'name': 'Costa Rica'}                                   67000          CR
# {'name': 'Croatia'}                                      68000          HR
# {'name': 'Cuba'}                                         69000          CU
# {'name': 'Angola'}                                        7000          AO
# {'name': 'Cyprus'}                                       70000          CY
# {'name': 'Czech Republic'}                               71000          CZ
# {'name': 'Denmark'}                                      73000          DK
# {'name': 'Djibouti'}                                     75000          DJ
# {'name': 'Dominica'}                                     76000          DM
# {'name': 'Dominican Republic'}                           77000          DO
# {'name': 'Ecuador'}                                      78000          EC
# {'name': 'Egypt'}                                        79000          EG
# {'name': 'Anguilla'}                                      8000          AI
# {'name': 'El Salvador'}                                  80000          SV
# {'name': 'Equatorial Guinea'}                            82000          GQ
# {'name': 'Eritrea'}                                      83000          ER
# {'name': 'Estonia'}                                      84000          EE
# {'name': 'Ethiopia'}                                     85000          ET
# {'name': 'Fiji'}                                         89000          FJ
# {'name': 'Azores'}                                         900       PT-20
# {'name': 'Antarctica'}                                    9000          AQ
# {'name': 'Finland'}                                      90000          FI
# {'name': 'France'}                                       92000          FR
# {'name': 'French Guiana'}                                93000          GF
# {'name': 'French Polynesia'}                             94000          PF
# {'name': 'Gabon'}                                        95000          GA
# {'name': 'Gambia, The'}                                  96000          GM
# {'name': 'Georgia'}                                      99000          GE
# NaN                                                        NaN         NaN
#
#                                                                                                   fra  \
# eng
# {'name': 'Afghanistan'}                                                       {'name': 'Afghanistan'}
# {'name': 'Antigua and Barbuda'}                                        {'name': 'Antigua-et-Barbuda'}
# {'name': 'Germany'}                                                             {'name': 'Allemagne'}
# {'name': 'Ghana'}                                                                   {'name': 'Ghana'}
# {'name': 'Greece'}                                                                  {'name': 'Grèce'}
# {'name': 'Greenland'}                                                           {'name': 'Groenland'}
# {'name': 'Grenada'}                                                               {'name': 'Grenade'}
# {'name': 'Argentina'}                                                           {'name': 'Argentine'}
# {'name': 'Guadeloupe'}                                                         {'name': 'Guadeloupe'}
# {'name': 'Guam'}                                                                     {'name': 'Guam'}
# {'name': 'Guatemala'}                                                           {'name': 'Guatemala'}
# {'name': 'Guinea'}                                                                 {'name': 'Guinée'}
# {'name': 'Guinea-Bissau'}                                                   {'name': 'Guinée-Bissau'}
# {'name': 'Guyana'}                                                                 {'name': 'Guyana'}
# {'name': 'Haiti'}                                                                   {'name': 'Haïti'}
# {'name': 'Hong Kong'}                                                           {'name': 'Hong Kong'}
# {'name': 'Honduras'}                                                             {'name': 'Honduras'}
# {'name': 'Hungary'}                                                               {'name': 'Hongrie'}
# {'name': 'Iceland'}                                                               {'name': 'Islande'}
# {'name': 'India'}                                                                    {'name': 'Inde'}
# {'name': 'Indonesia'}                                                           {'name': 'Indonésie'}
# {'name': 'Iran'}                                                                     {'name': 'Iran'}
# {'name': 'Iraq'}                                                                     {'name': 'Iraq'}
# {'name': 'Ireland'}                                                               {'name': 'Irlande'}
# {'name': 'Israel, the West Bank and the Gaza St...  {'name': 'Israël, la Cisjordanie et la bande d...
# {'name': 'Italy'}                                                                  {'name': 'Italie'}
# {'name': 'Côte d'Ivoire (Ivory Coast)'}                                     {'name': 'Côte d'Ivoire'}
# {'name': 'Jamaica'}                                                              {'name': 'Jamaïque'}
# {'name': 'Armenia'}                                                               {'name': 'Arménie'}
# {'name': 'Japan'}                                                                   {'name': 'Japon'}
# ...                                                                                               ...
# {'name': 'Republic of Congo (Brazzaville)'}             {'name': 'République du Congo (Brazzaville)'}
# {'name': 'Costa Rica'}                                                         {'name': 'Costa Rica'}
# {'name': 'Croatia'}                                                               {'name': 'Croatie'}
# {'name': 'Cuba'}                                                                     {'name': 'Cuba'}
# {'name': 'Angola'}                                                                 {'name': 'Angola'}
# {'name': 'Cyprus'}                                                                 {'name': 'Chypre'}
# {'name': 'Czech Republic'}                                             {'name': 'République tchèque'}
# {'name': 'Denmark'}                                                              {'name': 'Danemark'}
# {'name': 'Djibouti'}                                                             {'name': 'Djibouti'}
# {'name': 'Dominica'}                                                            {'name': 'Dominique'}
# {'name': 'Dominican Republic'}                                     {'name': 'République dominicaine'}
# {'name': 'Ecuador'}                                                              {'name': 'Équateur'}
# {'name': 'Egypt'}                                                                  {'name': 'Égypte'}
# {'name': 'Anguilla'}                                                             {'name': 'Anguilla'}
# {'name': 'El Salvador'}                                                          {'name': 'Salvador'}
# {'name': 'Equatorial Guinea'}                                          {'name': 'Guinée équatoriale'}
# {'name': 'Eritrea'}                                                              {'name': 'Érythrée'}
# {'name': 'Estonia'}                                                               {'name': 'Estonie'}
# {'name': 'Ethiopia'}                                                             {'name': 'Éthiopie'}
# {'name': 'Fiji'}                                                                    {'name': 'Fidji'}
# {'name': 'Azores'}                                                                 {'name': 'Açores'}
# {'name': 'Antarctica'}                                                        {'name': 'Antarctique'}
# {'name': 'Finland'}                                                              {'name': 'Finlande'}
# {'name': 'France'}                                                                 {'name': 'France'}
# {'name': 'French Guiana'}                                                {'name': 'Guyane française'}
# {'name': 'French Polynesia'}                                          {'name': 'Polynésie française'}
# {'name': 'Gabon'}                                                                   {'name': 'Gabon'}
# {'name': 'Gambia, The'}                                                            {'name': 'Gambie'}
# {'name': 'Georgia'}                                                               {'name': 'Géorgie'}
# NaN                                                                                               NaN
#
#                                                                                   offices-help-abroad  \
# eng
# {'name': 'Afghanistan'}                             {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Antigua and Barbuda'}                     {'refer-to-office-id': 25000, 'eng': {'closing...
# {'name': 'Germany'}                                 {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Ghana'}                                   {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Greece'}                                  {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Greenland'}                               {'refer-to-office-id': 73000, 'eng': {'closing...
# {'name': 'Grenada'}                                 {'refer-to-office-id': 25000, 'eng': {'closing...
# {'name': 'Argentina'}                               {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Guadeloupe'}                              {'refer-to-office-id': 25000, 'eng': {'closing...
# {'name': 'Guam'}                                    {'refer-to-office-id': 186000, 'eng': {'closin...
# {'name': 'Guatemala'}                               {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Guinea'}                                  {'refer-to-office-id': 260000, 'eng': {'closin...
# {'name': 'Guinea-Bissau'}                           {'refer-to-office-id': 260000, 'eng': {'closin...
# {'name': 'Guyana'}                                  {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Haiti'}                                   {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Hong Kong'}                               {'refer-to-office-id': 55305, 'eng': {'closing...
# {'name': 'Honduras'}                                {'refer-to-office-id': 67000, 'eng': {'closing...
# {'name': 'Hungary'}                                 {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Iceland'}                                 {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'India'}                                   {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Indonesia'}                               {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Iran'}                                    {'refer-to-office-id': 300002, 'eng': {'closin...
# {'name': 'Iraq'}                                    {'refer-to-office-id': 144000, 'eng': {'closin...
# {'name': 'Ireland'}                                 {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Israel, the West Bank and the Gaza St...  {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Italy'}                                   {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Côte d'Ivoire (Ivory Coast)'}             {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Jamaica'}                                 {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Armenia'}                                 {'refer-to-office-id': 249002, 'eng': {'closin...
# {'name': 'Japan'}                                   {'refer-to-office-id': '', 'eng': {'closing-te...
# ...                                                                                               ...
# {'name': 'Republic of Congo (Brazzaville)'}         {'refer-to-office-id': 332000, 'eng': {'closin...
# {'name': 'Costa Rica'}                              {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Croatia'}                                 {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Cuba'}                                    {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Angola'}                                  {'refer-to-office-id': 335000, 'eng': {'closin...
# {'name': 'Cyprus'}                                  {'refer-to-office-id': 106004, 'eng': {'closin...
# {'name': 'Czech Republic'}                          {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Denmark'}                                 {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Djibouti'}                                {'refer-to-office-id': 85000, 'eng': {'closing...
# {'name': 'Dominica'}                                {'refer-to-office-id': 25000, 'eng': {'closing...
# {'name': 'Dominican Republic'}                      {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Ecuador'}                                 {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Egypt'}                                   {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Anguilla'}                                {'refer-to-office-id': 25000, 'eng': {'closing...
# {'name': 'El Salvador'}                             {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Equatorial Guinea'}                       {'refer-to-office-id': 218004, 'eng': {'closin...
# {'name': 'Eritrea'}                                 {'refer-to-office-id': 277000, 'eng': {'closin...
# {'name': 'Estonia'}                                 {'refer-to-office-id': 281006, 'eng': {'closin...
# {'name': 'Ethiopia'}                                {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'Fiji'}                                    {'refer-to-office-id': 215000, 'eng': {'closin...
# {'name': 'Azores'}                                  {'refer-to-office-id': 242004, 'eng': {'closin...
# {'name': 'Antarctica'}                              {'refer-to-office-id': 22222222, 'eng': {'clos...
# {'name': 'Finland'}                                 {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'France'}                                  {'refer-to-office-id': '', 'eng': {'closing-te...
# {'name': 'French Guiana'}                           {'refer-to-office-id': 116000, 'eng': {'closin...
# {'name': 'French Polynesia'}                        {'refer-to-office-id': 215000, 'eng': {'closin...
# {'name': 'Gabon'}                                   {'refer-to-office-id': 47004, 'eng': {'closing...
# {'name': 'Gambia, The'}                             {'refer-to-office-id': 260000, 'eng': {'closin...
# {'name': 'Georgia'}                                 {'refer-to-office-id': 300002, 'eng': {'closin...
# NaN                                                                                               NaN
#
#                                                      0
# eng
# {'name': 'Afghanistan'}                            NaN
# {'name': 'Antigua and Barbuda'}                    NaN
# {'name': 'Germany'}                                NaN
# {'name': 'Ghana'}                                  NaN
# {'name': 'Greece'}                                 NaN
# {'name': 'Greenland'}                              NaN
# {'name': 'Grenada'}                                NaN
# {'name': 'Argentina'}                              NaN
# {'name': 'Guadeloupe'}                             NaN
# {'name': 'Guam'}                                   NaN
# {'name': 'Guatemala'}                              NaN
# {'name': 'Guinea'}                                 NaN
# {'name': 'Guinea-Bissau'}                          NaN
# {'name': 'Guyana'}                                 NaN
# {'name': 'Haiti'}                                  NaN
# {'name': 'Hong Kong'}                              NaN
# {'name': 'Honduras'}                               NaN
# {'name': 'Hungary'}                                NaN
# {'name': 'Iceland'}                                NaN
# {'name': 'India'}                                  NaN
# {'name': 'Indonesia'}                              NaN
# {'name': 'Iran'}                                   NaN
# {'name': 'Iraq'}                                   NaN
# {'name': 'Ireland'}                                NaN
# {'name': 'Israel, the West Bank and the Gaza St... NaN
# {'name': 'Italy'}                                  NaN
# {'name': 'Côte d'Ivoire (Ivory Coast)'}            NaN
# {'name': 'Jamaica'}                                NaN
# {'name': 'Armenia'}                                NaN
# {'name': 'Japan'}                                  NaN
# ...                                                 ..
# {'name': 'Republic of Congo (Brazzaville)'}        NaN
# {'name': 'Costa Rica'}                             NaN
# {'name': 'Croatia'}                                NaN
# {'name': 'Cuba'}                                   NaN
# {'name': 'Angola'}                                 NaN
# {'name': 'Cyprus'}                                 NaN
# {'name': 'Czech Republic'}                         NaN
# {'name': 'Denmark'}                                NaN
# {'name': 'Djibouti'}                               NaN
# {'name': 'Dominica'}                               NaN
# {'name': 'Dominican Republic'}                     NaN
# {'name': 'Ecuador'}                                NaN
# {'name': 'Egypt'}                                  NaN
# {'name': 'Anguilla'}                               NaN
# {'name': 'El Salvador'}                            NaN
# {'name': 'Equatorial Guinea'}                      NaN
# {'name': 'Eritrea'}                                NaN
# {'name': 'Estonia'}                                NaN
# {'name': 'Ethiopia'}                               NaN
# {'name': 'Fiji'}                                   NaN
# {'name': 'Azores'}                                 NaN
# {'name': 'Antarctica'}                             NaN
# {'name': 'Finland'}                                NaN
# {'name': 'France'}                                 NaN
# {'name': 'French Guiana'}                          NaN
# {'name': 'French Polynesia'}                       NaN
# {'name': 'Gabon'}                                  NaN
# {'name': 'Gambia, The'}                            NaN
# {'name': 'Georgia'}                                NaN
# NaN                                                NaN
#
# [230 rows x 5 columns]

# %% [markdown]
# ####
